# %% [markdown]
# <h1>ECE-GY 9293 HW5 Guandong Kou (gk1675)</h1>

# %%
run ../styles.ipynb
# Out:
# <style>
# h1 {
#     text-align:center;
# }
# img[alt="image.png"] {
#     width: 60%;
# }
# hr {
#     height: 1px;
# }
# </style>

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## a1)
# Shortest augmenting path

# %% [markdown]
# ## a2)
# Largest augmenting path

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# The source code of this Jupyter Notebook will only be pushed to [Guandong Kou's GitHub repository](https://github.com/Kou-Guandong/NYU_9293_Network_Science_and_Optimization) after the due date.
