# %% [markdown]
# <h1>ECE-GY 9293 HW2 Guandong Kou (gk1675)</h1>

# %%
run ../styles.ipynb
# Out:
# <style>
# h1 {
#     text-align:center;
# }
# img[alt="image.png"] {
#     width: 60%;
# }
# hr {
#     height: 1px;
# }
# </style>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 1 (11.4 from Newman)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## Problem 2 (11.7 from Newman)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## Problem 3 (12.3 from Newman)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## Problem 4 (12.7 from Newman)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## Extra Problem \#1 (7.6 Newman)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# The source code of this Jupyter Notebook will only be pushed to [Guandong Kou's GitHub repository](https://github.com/Kou-Guandong/NYU_9293_Network_Science_and_Optimization) after the due date.
